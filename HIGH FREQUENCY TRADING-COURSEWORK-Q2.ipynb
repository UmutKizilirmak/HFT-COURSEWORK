# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: nbformat in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb) (5.1.3)
# Requirement already satisfied: IPython in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb) (7.29.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: pygments in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (2.10.0)
# Requirement already satisfied: backcall in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (58.0.4)
# Requirement already satisfied: pickleshare in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: appnope in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.18.0)
# Requirement already satisfied: decorator in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jupyter-core in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (4.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (3.2.0)
# Requirement already satisfied: ipython-genutils in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->import-ipynb) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->import-ipynb) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/umutkizilirmak/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->import-ipynb) (21.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries.
import numpy as np
import import_ipynb
import Liquidation_Permanent_Price_Impact_helper as lppi_helpers
# Out:
# importing Jupyter notebook from Liquidation_Permanent_Price_Impact_helper.ipynb

# %%
# Parameter settings
T = 1
Ndt = 6.5 * 3600
dt = T / Ndt
t = np.arange(0, T + dt, dt)

k = 0.001
b = 0.002

tau = T - t
tt = np.arange(0, 1 + 1 / 10, 1 / 10)

myphi = np.array([10e-10, 0.001, 0.01, 0.1])
symb = np.array(["o", "*", "+", "^"])

alpha = 100

# %%
# Fig 6.2 of Page 148
lppi_helpers.plot_inventory_trading_speed(0.01, myphi, symb, t, tt, T, b, k, [r"$\phi = $" + str(i) for i in myphi], main=r"$\alpha = 0.01$")
lppi_helpers.plot_inventory_trading_speed(100, myphi, symb, t, tt, T, b, k, [r"$\phi = $" + str(i) for i in myphi], main=r"$\alpha = +\infty$")
